# %%
import pandas as pd
# Out:
# /tmp/ipykernel_31544/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df_animes = pd.read_csv('./anime_final.csv')
df_animes
# Out:
#        Unnamed: 0  anime_id  \
# 0               0     32281
# 1               1      5114
# 2               2     28977
# 3               3      9253
# 4               4      9969
# ...           ...       ...
# 12189       12189      9316
# 12190       12190      5543
# 12191       12191      5621
# 12192       12192      6133
# 12193       12193     26081
#
#                                                     name  \
# 0                                         Kimi no Na wa.
# 1                       Fullmetal Alchemist: Brotherhood
# 2                                               Gintama°
# 3                                            Steins;Gate
# 4                                          Gintama&#039;
# ...                                                  ...
# 12189       Toushindai My Lover: Minami tai Mecha-Minami
# 12190                                        Under World
# 12191                     Violence Gekiga David no Hoshi
# ...

# %%
pd.DataFrame(df_animes['type'].unique()).to_csv('./TABLAS/TYPES.csv')
