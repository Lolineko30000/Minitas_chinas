# %%
import pandas as pd

# %%
df_genre = pd.read_csv("./GENRE.csv")
df_genre
# Out:
#     ID_GENRE          GENRE
# 0          0          Drama
# 1          1        Romance
# 2          2         School
# 3          3   Supernatural
# 4          4         Action
# 5          5      Adventure
# 6          6        Fantasy
# 7          7          Magic
# 8          8       Military
# 9          9        Shounen
# 10        10         Comedy
# 11        11     Historical
# 12        12         Parody
# 13        13        Samurai
# 14        14         Sci-Fi
# 15        15       Thriller
# 16        16         Sports
# 17        17    Super Power
# 18        18          Space
# 19        19  Slice of Life
# 20        20          Mecha
# 21        21          Music
# 22        22        Mystery
# 23        23         Seinen
# 24        24   Martial Arts
# 25        25        Vampire
# 26        26         Shoujo
# 27        27         Horror
# 28        28         Police
# 29        29  Psychological
# 30        30         Demons
# 31        31          Ecchi
# ...

# %%
df_genre.dtypes
# Out:
# ID_GENRE     int64
# GENRE       object
# dtype: object

# %%
df_genre = df_genre[['ID_GENRE','GENRE']]

# %%
df_genre.to_csv('./GENRE.csv', index=False)
