# %%
import pandas as pd

# %%
df_genre_anime = pd.read_csv("./GENRE_ANIME.csv")
df_genre_anime
# Out:
#        ID_ANIME  ID_GENRE
# 0         32281         0
# 1          5114         0
# 2         32935         0
# 3           820         0
# 4          4181         0
# ...         ...       ...
# 36080      5393        43
# 36081     13917        43
# 36082      5383        43
# 36083     30663        43
# 36084     34382        43
#
# [36085 rows x 2 columns]

# %%
df_genre_anime.isna().sum()
# Out:
# ID_ANIME    0
# ID_GENRE    0
# dtype: int64

# %%
df_genre_anime.dtypes
# Out:
# ID_ANIME    int64
# ID_GENRE    int64
# dtype: object

# %%
df_genre_anime.to_csv('./TABLAS/GENRE_ANIME.csv',index=False)
