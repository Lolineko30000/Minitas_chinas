# %%
import pandas as pd

# %%
df_types = pd.read_csv("./TYPES.csv")
df_types
# Out:
#    ID_TYPES    TYPES
# 0         0    Movie
# 1         1       TV
# 2         2      OVA
# 3         3  Special
# 4         4    Music
# 5         5      ONA

# %%
df_types.dtypes
# Out:
# ID_TYPES     int64
# TYPES       object
# dtype: object

# %%
df_types.to_csv('./TYPES.csv')
