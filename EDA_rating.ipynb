# %% [markdown]
# # Importación de librerías

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Funciones útiles

# %% [markdown]
# # Carga de datos

# %%
df_rating = pd.read_csv('./Datos_Enriquecidos/rating_enriquecido.csv')

# %% [markdown]
# # EDA

# %%
df_rating
# Out:
#           user_id  anime_id  rating
# 0               1        21       9
# 1               1        48       7
# 2               1       320       5
# 3               1        49       8
# 4               1       304       8
# ...           ...       ...     ...
# 24436719    71957     16498       9
# 24436720    71957     19951       7
# 24436721    71957     21843       7
# 24436722    71957     22319      10
# 24436723    71957     27899       9
#
# [24436724 rows x 3 columns]

# %%
df_rating.dtypes
# Out:
# user_id     int64
# anime_id    int64
# rating      int64
# dtype: object

# %% [markdown]
# # Visualización

# %% [markdown]
# ## Estadísticos

# %%
df_rating.describe()
# Out:
#             user_id      anime_id        rating
# count  2.443672e+07  2.443672e+07  2.443672e+07
# mean   4.385614e+05  9.748595e+03  7.615574e+00
# std    3.670992e+05  1.204943e+04  1.677738e+00
# min    1.000000e+00  1.000000e+00 -1.000000e+00
# 25%    9.559600e+04  8.740000e+02  7.000000e+00
# 50%    3.867130e+05  4.726000e+03  8.000000e+00
# 75%    5.269330e+05  1.314500e+04  9.000000e+00
# max    1.291097e+06  5.608500e+04  1.000000e+01

# %% [markdown]
# ## Muestra representativa

# %%
muestra = df_rating.sample(frac=0.01)

# %%
muestra.describe()
# Out:
#             user_id       anime_id         rating
# count  2.443670e+05  244367.000000  244367.000000
# mean   4.401569e+05    9763.319642       7.617710
# std    3.686867e+05   12070.865946       1.680413
# min    1.000000e+00       1.000000      -1.000000
# 25%    9.567500e+04     874.000000       7.000000
# 50%    3.872340e+05    4725.000000       8.000000
# 75%    5.281390e+05   13203.000000       9.000000
# max    1.291087e+06   55818.000000      10.000000

# %% [markdown]
# ## Histograma

# %%
px.histogram(muestra['rating'])
